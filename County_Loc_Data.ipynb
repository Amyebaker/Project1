# %%
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt

# %%
county_loc = pd.read_csv("country_loc.csv")

# %%
county_loc.head()
# Out:
#    Unnamed: 0 state         county  Per Capita Income 2021  \
# 0           0    VA  Arlington, VA                  107603
# 1           1    VA    Loudoun, VA                   90254
# 2           2    VA    Henrico, VA                   74650
# 3           3    VA  Goochland, VA                  110781
# 4           4    VA   Stafford, VA                   62954
#
#    Adjusted Per Capita Personal Income 2021  Count of Associate Degrees  \
# 0                                 105700.39                       19573
# 1                                  88658.15                       52006
# 2                                  73330.06                       60829
# 3                                 108822.20                        4586
# 4                                  61840.86                       28316
#
#    Count of Bachelor Degrees or Higher  Percent of No College  \
# 0                               132394                  12.95
# ...

# %%
map_plot1 = county_loc.hvplot.points("Lng","Lat",geo=True,tiles="OSM",size= "Adjusted Per Capita Personal Income 2021",scale= .0025, color= "county", alpha=.75)

map_plot1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (county,Adjusted Per Capita Personal Income 2021)

# %%
plt.savefig("Count_Map.png")
